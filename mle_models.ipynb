# %% [markdown]
# ## Bacterial rates analyses summary
#
# - Pull marginal likelihoods from out_data.txt, which is obtained by running get_mle.sh in shell

# %%
import pandas as pd
import numpy as np
import re, os, sys, subprocess
import matplotlib.pyplot as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Pull mles: in the directory, run ./get_mles.sh The output is in out_data.txt

# %%
mles_raw_file = open('out_data.txt', 'r').readlines()
mles_raw_file[:10]
# Out:
# ['B_petrussis_s_bs.mle.log\n',
#  'log marginal likelihood (using path sampling) from pathLikelihood.delta = -34404.284623289815\n',
#  'log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34415.362186518134\n',
#  'B_petrussis_sc.mle.log\n',
#  'log marginal likelihood (using path sampling) from pathLikelihood.delta = -34421.51064882376\n',
#  'log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34428.58947592618\n',
#  'B_petrussis_ucl_bs.mle.log\n',
#  'log marginal likelihood (using path sampling) from pathLikelihood.delta = -34344.34575802659\n',
#  'log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34355.75411472933\n',
#  'B_petrussis_ucl_s.mle.log\n']

# %%
mle_data = pd.DataFrame(np.empty(shape = (1, 3)))

for i in range(len(mles_raw_file)):
    print mles_raw_file[i]
    if re.match('^log.+', mles_raw_file[i]) is None:
        temp_name = re.sub('[.]|mle[.]|log|\n', '', mles_raw_file[i])
        temp_ps = float(re.sub('=| ', '', re.findall('=.+', mles_raw_file[i+1])[0]))
        temp_ss = float(re.sub('=| ', '', re.findall('=.+', mles_raw_file[i+2])[0]))
        temp_frame = pd.DataFrame([temp_name, temp_ps, temp_ss]).transpose()
        mle_data = pd.concat([mle_data, temp_frame], ignore_index=True, axis=0)

mle_data = mle_data.ix[1:, ]
mle_data.index = [i for i in range(mle_data.shape[0])]
mle_data.columns = ['file_name', 'ps', 'ss']
# Out:
# B_petrussis_s_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -34404.284623289815
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34415.362186518134
#
# B_petrussis_sc.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -34421.51064882376
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34428.58947592618
#
# B_petrussis_ucl_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -34344.34575802659
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34355.75411472933
#
# B_petrussis_ucl_s.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -34352.35706005035
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -34358.847443423074
#
# cholera_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -13236.967875298275
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -13240.045330830379
#
# cholera_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -13223.635434323865
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -13249.090914554336
#
# cholera_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -13110.256943606026
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -13117.713473310301
#
# cholera_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -13120.352849698455
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -13135.369128392416
#
# mleprae_no_s15_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -3883.1823600498597
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -3870.708924862818
#
# mleprae_no_s15_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -3890.826658570453
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -2727.9949489701708
#
# mleprae_no_s15_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -3880.5457443448186
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -3874.1851135015536
#
# mleprae_no_s15_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -3886.9897957861954
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -3463.7896248205852
#
# M_tuberculosis_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -48883.17318650114
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -48907.912908851846
#
# M_tuberculosis_strict_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -48856.854870470765
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -48891.08022629439
#
# M_tuberculosis_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -48865.94959372418
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -48904.92059198222
#
# M_tuberculosis_ucld_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -48844.65599917934
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -48892.42075758349
#
# neisseria_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -59959.99406880174
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -59969.30518668513
#
# neisseria_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -59988.504026847404
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -59992.26700646569
#
# neisseria_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -58959.21295502993
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -58964.38852379217
#
# neisseria_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -59028.40097242765
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -59032.063806926
#
# p_aeruginosa_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18713.383230745774
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18713.378287498974
#
# p_aeruginosa_strict_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18709.62929101041
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18709.99063116484
#
# p_aeruginosa_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18444.261768913762
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18444.647551289752
#
# p_aeruginosa_ucld_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18448.090886558723
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18447.94933614708
#
# shigella_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -32386.10109410303
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -32370.1737451956
#
# shigella_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -32340.300671067453
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -32384.15575550674
#
# shigella_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -32406.99697872492
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -32351.558236984678
#
# shigella_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -32337.634053884547
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -32352.627647079647
#
# S_pneu_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -17268.466352082218
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -17267.618997594735
#
# S_pneu_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -17274.22896732699
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -17179.082521990167
#
# S_pneu_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -16891.85616041426
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -16851.586186030483
#
# S_pneu_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -16942.853841540287
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -16942.296729646994
#
# ST22_dates_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -108012.52308553718
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -108012.37266014642
#
# ST22_dates_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -101982.93757378118
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -101981.447367811
#
# ST22_dates_ucld_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -96871.4341819853
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -96870.44032416203
#
# ST22_dates_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -92837.97778209478
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -92837.93342983918
#
# Typhi_reduced_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -4867.794671687845
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -4868.133817557034
#
# Typhi_reduced_strict_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -4837.908458831957
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -4838.454620805132
#
# Typhi_reduced_ucld_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -4768.60437139518
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -4768.8121123041155
#
# Typhi_reduced_ucld_skyline.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -4683.692353855108
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -4684.08392864451
#
# ypestis_strict_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18744.651580243597
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18820.0266555626
#
# ypestis_strict_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18703.647440253986
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18855.224242303782
#
# ypestis_ucln_bs.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18532.554363649146
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18628.22178131048
#
# ypestis_ucln_constant.mle.log
#
# log marginal likelihood (using path sampling) from pathLikelihood.delta = -18554.668203700516
#
# log marginal likelihood (using stepping stone sampling) from pathLikelihood.delta = -18673.483922551095

# %%
mle_data.head()
# Out:
#             file_name        ps        ss
# 0    B_petrussis_s_bs -34404.28 -34415.36
# 1      B_petrussis_sc -34421.51 -34428.59
# 2  B_petrussis_ucl_bs -34344.35 -34355.75
# 3   B_petrussis_ucl_s -34352.36 -34358.85
# 4   cholera_strict_bs -13236.97 -13240.05

# %%
rates_data = np.empty(shape = (1, 3))
for i in mle_data['file_name']:
    temp_file = pd.read_csv(i+'.log', comment='#', sep = '\t')
    temp_rate_name = [c_ for c_ in temp_file.keys() if not re.match('ucld[.]mean|clock[.]rate', c_) is None]
    temp_data = np.concatenate([np.mean(temp_file[temp_rate_name]), np.percentile(temp_file[temp_rate_name], [2.5, 97.5])])
    rates_data = np.vstack([rates_data, temp_data])
rates_data = pd.DataFrame(rates_data[1:])

# %%
print rates_data.shape
print mle_data.shape
# Out:
# (44, 3)
# (44, 3)

# %%
mle_data.head()
# Out:
#             file_name        ps        ss
# 0    B_petrussis_s_bs -34404.28 -34415.36
# 1      B_petrussis_sc -34421.51 -34428.59
# 2  B_petrussis_ucl_bs -34344.35 -34355.75
# 3   B_petrussis_ucl_s -34352.36 -34358.85
# 4   cholera_strict_bs -13236.97 -13240.05

# %%
summary_data = pd.concat([mle_data, rates_data], ignore_index=True, axis = 1)

# %%
summary_data.columns = ['file_name', 'ps', 'ss', 'mean_rate', 'lowerHPD', 'higherHPD']
summary_data.head()
# Out:
#             file_name        ps        ss  mean_rate  lowerHPD  higherHPD
# 0    B_petrussis_s_bs -34404.28 -34415.36   0.000116  0.000101   0.000120
# 1      B_petrussis_sc -34421.51 -34428.59   0.000118  0.000104   0.000121
# 2  B_petrussis_ucl_bs -34344.35 -34355.75   0.000121  0.000106   0.000134
# 3   B_petrussis_ucl_s -34352.36 -34358.85   0.000124  0.000111   0.000137
# 4   cholera_strict_bs -13236.97 -13240.05   0.001271  0.001134   0.001396

# %%
#Next: select each bacteria type. For each type select best, and set up randomisations to validate the estimates.
summary_data.shape
# Out:
# (44, 6)

# %%
summary_data = pd.concat([summary_data, pd.DataFrame(np.empty(shape = (summary_data.shape[0], 2)))], axis = 1, ignore_index=True)
summary_data.columns = ['file_name', 'ps', 'ss', 'mean_rate', 'lowerHPD', 'higherHPD', 'genus', 'best_ML']

# %%
summary_data.head()
# Out:
#             file_name        ps        ss  mean_rate  lowerHPD  higherHPD  \
# 0    B_petrussis_s_bs -34404.28 -34415.36   0.000116  0.000101   0.000120
# 1      B_petrussis_sc -34421.51 -34428.59   0.000118  0.000104   0.000121
# 2  B_petrussis_ucl_bs -34344.35 -34355.75   0.000121  0.000106   0.000134
# 3   B_petrussis_ucl_s -34352.36 -34358.85   0.000124  0.000111   0.000137
# 4   cholera_strict_bs -13236.97 -13240.05   0.001271  0.001134   0.001396
#
#    genus  best_ML
# 0      1        0
# 1      1        0
# 2      1        0
# 3      1        0
# 4      1        0

# %%
for i in range(summary_data.shape[0]):
    summary_data.ix[i, 'genus'] = re.split('_', summary_data.ix[i, 'file_name'])[0]
summary_data
# Out:
#                          file_name        ps        ss  mean_rate  lowerHPD  \
# 0                 B_petrussis_s_bs -34404.28 -34415.36   0.000116  0.000101
# 1                   B_petrussis_sc -34421.51 -34428.59   0.000118  0.000104
# 2               B_petrussis_ucl_bs -34344.35 -34355.75   0.000121  0.000106
# 3                B_petrussis_ucl_s -34352.36 -34358.85   0.000124  0.000111
# 4                cholera_strict_bs -13236.97 -13240.05   0.001271  0.001134
# 5          cholera_strict_constant -13223.64 -13249.09   0.001270  0.001135
# 6                  cholera_ucld_bs -13110.26 -13117.71   0.001858  0.000993
# 7            cholera_ucld_constant -13120.35 -13135.37   0.001740  0.000739
# 8         mleprae_no_s15_strict_bs -3883.182 -3870.709   0.000057  0.000028
# 9   mleprae_no_s15_strict_constant -3890.827 -2727.995   0.000049  0.000028
# 10          mleprae_no_s15_ucld_bs -3880.546 -3874.185   0.000086  0.000028
# 11    mleprae_no_s15_ucld_constant  -3886.99  -3463.79   0.000163  0.000028
# 12  M_tuberculosis_strict_constant -48883.17 -48907.91   0.000045  0.000003
# 13   M_tuberculosis_strict_skyline -48856.85 -48891.08   0.000043  0.000007
# 14    M_tuberculosis_ucld_constant -48865.95 -48904.92   0.000052  0.000007
# 15     M_tuberculosis_ucld_skyline -48844.66 -48892.42   0.000046  0.000006
# 16             neisseria_strict_bs -59959.99 -59969.31   0.000067  0.000020
# 17       neisseria_strict_constant  -59988.5 -59992.27   0.000093  0.000046
# 18               neisseria_ucld_bs -58959.21 -58964.39   0.000502  0.000077
# 19         neisseria_ucld_constant  -59028.4 -59032.06   0.001219  0.000310
# 20    p_aeruginosa_strict_constant -18713.38 -18713.38   0.000279  0.000238
# 21     p_aeruginosa_strict_skyline -18709.63 -18709.99   0.000279  0.000237
# 22      p_aeruginosa_ucld_constant -18444.26 -18444.65   0.000539  0.000361
# 23       p_aeruginosa_ucld_skyline -18448.09 -18447.95   0.000562  0.000383
# 24              shigella_strict_bs  -32386.1 -32370.17   0.000413  0.000284
# 25        shigella_strict_constant  -32340.3 -32384.16   0.000412  0.000284
# 26                shigella_ucld_bs    -32407 -32351.56   0.000333  0.000278
# 27          shigella_ucld_constant -32337.63 -32352.63   0.000334  0.000283
# 28                S_pneu_strict_bs -17268.47 -17267.62   0.000245  0.000177
# 29          S_pneu_strict_constant -17274.23 -17179.08   0.000230  0.000158
# 30                  S_pneu_ucld_bs -16891.86 -16851.59   0.000413  0.000132
# 31            S_pneu_ucld_constant -16942.85  -16942.3   0.000715  0.000229
# 32            ST22_dates_strict_bs -108012.5 -108012.4   0.000350  0.000324
# 33      ST22_dates_strict_constant -101982.9 -101981.4   0.000324  0.000295
# 34              ST22_dates_ucld_bs -96871.43 -96870.44   0.000484  0.000386
# 35        ST22_dates_ucld_constant -92837.98 -92837.93   0.000479  0.000383
# 36   Typhi_reduced_strict_constant -4867.795 -4868.134   0.000395  0.000292
# 37    Typhi_reduced_strict_skyline -4837.908 -4838.455   0.000554  0.000454
# 38     Typhi_reduced_ucld_constant -4768.604 -4768.812   0.000623  0.000405
# 39      Typhi_reduced_ucld_skyline -4683.692 -4684.084   0.000695  0.000512
# 40               ypestis_strict_bs -18744.65 -18820.03   0.000023  0.000015
# 41         ypestis_strict_constant -18703.65 -18855.22   0.000022  0.000014
# 42                 ypestis_ucln_bs -18532.55 -18628.22   0.000030  0.000014
# 43           ypestis_ucln_constant -18554.67 -18673.48   0.000023  0.000013
#
#     higherHPD      genus best_ML
# 0    0.000120          B       0
# 1    0.000121          B       0
# 2    0.000134          B    BEST
# 3    0.000137          B       0
# 4    0.001396    cholera       0
# 5    0.001394    cholera       0
# 6    0.002511    cholera    BEST
# 7    0.002322    cholera       0
# 8    0.000070    mleprae       0
# 9    0.000066    mleprae       0
# 10   0.000084    mleprae    BEST
# 11   0.000071    mleprae       0
# 12   0.000099          M       0
# 13   0.000089          M       0
# 14   0.000110          M       0
# 15   0.000103          M    BEST
# 16   0.000239  neisseria       0
# 17   0.000161  neisseria       0
# 18   0.001373  neisseria    BEST
# 19   0.002925  neisseria       0
# 20   0.000322          p       0
# 21   0.000322          p       0
# 22   0.000793          p    BEST
# 23   0.000831          p       0
# 24   0.000343   shigella       0
# 25   0.000342   shigella       0
# 26   0.000381   shigella       0
# 27   0.000382   shigella    BEST
# 28   0.000315          S       0
# 29   0.000309          S       0
# 30   0.000745          S    BEST
# 31   0.001783          S       0
# 32   0.000374       ST22       0
# 33   0.000349       ST22       0
# 34   0.000704       ST22       0
# 35   0.000984       ST22    BEST
# 36   0.000521      Typhi       0
# 37   0.000652      Typhi       0
# 38   0.001002      Typhi       0
# 39   0.000966      Typhi    BEST
# 40   0.000021    ypestis       0
# 41   0.000020    ypestis       0
# 42   0.000055    ypestis    BEST
# 43   0.000024    ypestis       0

# %% [markdown]
# ### Find the model with the highest ML
#
# - These should be run for the date randomisation test

# %%
genus_set = set(summary_data.ix[:, 'genus'])
print genus_set
for g in genus_set:
    ps_temp = np.max(summary_data.ix[summary_data.ix[:, 'genus'] == g, 'ps'])
    print ps_temp
    
    #Find location of best mle for genus
    genus_best = []
    for r in range(summary_data.shape[0]):    
        if (summary_data.ix[r, 'ps'] ==  ps_temp) and (summary_data.ix[r, 'genus'] == g):
            genus_best.append(r)

#    max_loc = np.array([(summary_data.ix[:, 'ps'] ==  ps_temp), (summary_data.ix[:, 'genus'] == g)])

#    max_loc = max_loc.transpose()
#    max_loc = np.where([all(max_loc[i, :]) for i in range(max_loc.shape[0])])[0][0]
    
    summary_data.ix[genus_best, 'best_ML'] = 'BEST'
# Out:
# set(['Typhi', 'B', 'cholera', 'M', 'ypestis', 'p', 'S', 'shigella', 'neisseria', 'ST22', 'mleprae'])
# -4683.69235386
# -34344.345758
# -13110.2569436
# -48844.6559992
# -18532.5543636
# -18444.2617689
# -16891.8561604
# -32337.6340539
# -58959.212955
# -92837.9777821
# -3880.54574434

# %%
summary_data.ix[summary_data.ix[:, 'best_ML'] == 'BEST', :]
# Out:
#                       file_name        ps        ss  mean_rate  lowerHPD  \
# 2            B_petrussis_ucl_bs -34344.35 -34355.75   0.000121  0.000106
# 6               cholera_ucld_bs -13110.26 -13117.71   0.001858  0.000993
# 10       mleprae_no_s15_ucld_bs -3880.546 -3874.185   0.000086  0.000028
# 15  M_tuberculosis_ucld_skyline -48844.66 -48892.42   0.000046  0.000006
# 18            neisseria_ucld_bs -58959.21 -58964.39   0.000502  0.000077
# 22   p_aeruginosa_ucld_constant -18444.26 -18444.65   0.000539  0.000361
# 27       shigella_ucld_constant -32337.63 -32352.63   0.000334  0.000283
# 30               S_pneu_ucld_bs -16891.86 -16851.59   0.000413  0.000132
# 35     ST22_dates_ucld_constant -92837.98 -92837.93   0.000479  0.000383
# 39   Typhi_reduced_ucld_skyline -4683.692 -4684.084   0.000695  0.000512
# 42              ypestis_ucln_bs -18532.55 -18628.22   0.000030  0.000014
#
#     higherHPD      genus best_ML
# 2    0.000134          B    BEST
# 6    0.002511    cholera    BEST
# 10   0.000084    mleprae    BEST
# 15   0.000103          M    BEST
# 18   0.001373  neisseria    BEST
# 22   0.000793          p    BEST
# 27   0.000382   shigella    BEST
# 30   0.000745          S    BEST
# 35   0.000984       ST22    BEST
# 39   0.000966      Typhi    BEST
# 42   0.000055    ypestis    BEST

# %%
summary_data.ix[summary_data.ix[:, 'best_ML'] == 'BEST', :].to_csv('res_10_datasets.csv', index = False)

# %%
summary_data.ix[summary_data.ix[:, 'best_ML'] == 'BEST', :]
# Out:
# (10, 8)
