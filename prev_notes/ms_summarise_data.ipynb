# %%
import re
import pandas as pd
import numpy as np
import scipy.stats as sc

# %%
metadata = pd.read_excel('metadata1.xlsx')

# %%
beast_rates = pd.DataFrame([metadata.Name, metadata.species, metadata.beast_genomic_rate, metadata.beast_genomic_rate_hpd, metadata.temp_stucture_degree, metadata.sampling_time])

# %%
beast_rates = beast_rates.transpose()

# %%
beast_rates.ix[beast_rates.beast_genomic_rate.argsort(), :]
# Out:
#                                 Name                     species  \
# 0                          M. leprae        Mycobacterium leprae
# 1                          Y. pestis             Yersinia pestis
# 2        Y. pestis (second pandemic)             Yersinia pestis
# 35     M. tuberculosis (NW mummies)   Mycobacterium tuberculosis
# 3          M. tuberculosis Lineage 4  Mycobacterium tuberculosis
# 4                      N. meningitis      Neisseria meningitidis
# 5        S. Paratyphi A (two clades)         Salmonella enterica
# 6           S. Paratyphi A (clade 1)         Salmonella enterica
# 7           S. Paratyphi A (clade 2)         Salmonella enterica
# 8                       B. pertussis        Bordetella pertussis
# 9                       S. Typhi H58         Salmonella enterica
# 10         M. tuberculosis Lineage 2  Mycobacterium tuberculosis
# 11               S. pneumoniae PMEN1    Streptococcus pneumoniae
# ...

# %%
reg_rates = pd.DataFrame([metadata.Name, metadata.species, metadata.regression_rate, metadata.reg_conf_int ]).transpose()

# %%
for i in metadata.reg_conf_int:
    i, j = re.split(',', re.sub('[[]|[]]', '', i))
    print float(j), float(j)
# Out:
# 5.94495453764e-09 5.94495453764e-09
# 1.1506284245e-08 1.1506284245e-08
# -2.86482763261e-09 -2.86482763261e-09
# 8.38185960002e-08 8.38185960002e-08
# 8.47757243962e-07 8.47757243962e-07
# 6.39192287761e-08 6.39192287761e-08
# 7.42615512864e-08 7.42615512864e-08
# 8.92664194607e-08 8.92664194607e-08
# 2.77216941572e-07 2.77216941572e-07
# 1.53176385807e-07 1.53176385807e-07
# 1.46707611793e-07 1.46707611793e-07
# 2.23065530017e-07 2.23065530017e-07
# 3.19358295986e-07 3.19358295986e-07
# 1.66969845078e-07 1.66969845078e-07
# 2.54042701156e-07 2.54042701156e-07
# 3.51939154812e-07 3.51939154812e-07
# 2.94272244578e-07 2.94272244578e-07
# 3.23091992962e-07 3.23091992962e-07
# 7.34088750104e-07 7.34088750104e-07
# 6.67243140066e-07 6.67243140066e-07
# 5.06658573625e-07 5.06658573625e-07
# 1.0294835629e-06 1.0294835629e-06
# 8.44943287267e-07 8.44943287267e-07
# 8.4773869528e-07 8.4773869528e-07
# 2.09564606834e-06 2.09564606834e-06
# 1.32453437953e-06 1.32453437953e-06
# ...

# %%
reg_rates.ix[reg_rates.regression_rate.argsort(), :]
# Out:
#                                 Name                     species  \
# 10         M. tuberculosis Lineage 2  Mycobacterium tuberculosis
# 2        Y. pestis (second pandemic)             Yersinia pestis
# 0                          M. leprae        Mycobacterium leprae
# 1                          Y. pestis             Yersinia pestis
# 6           S. Paratyphi A (clade 1)         Salmonella enterica
# 5        S. Paratyphi A (two clades)         Salmonella enterica
# 35     M. tuberculosis (NW mummies)   Mycobacterium tuberculosis
# 3          M. tuberculosis Lineage 4  Mycobacterium tuberculosis
# 7           S. Paratyphi A (clade 2)         Salmonella enterica
# 13                          S. Agona         Salmonella enterica
# 9                       S. Typhi H58         Salmonella enterica
# 11               S. pneumoniae PMEN1    Streptococcus pneumoniae
# 14                       S. Kentucky         Salmonella enterica
# ...

# %%
metadata.reg_conf_int
# Out:
# 0      [3.31368851652756e-09,5.94495453763988e-09]
# 1       [2.25703733503865e-09,1.1506284244963e-08]
# 2     [-9.66727322480169e-09,-2.8648276326086e-09]
# 3      [4.21128981083466e-08,8.38185960002013e-08]
# 4      [-1.8053651805395e-07,8.47757243962053e-07]
# 5      [4.47470600113851e-08,6.39192287760676e-08]
# 6      [2.11808730869121e-08,7.42615512864466e-08]
# 7      [4.73471409311792e-08,8.92664194607145e-08]
# 8      [2.24250043312779e-07,2.77216941572175e-07]
# 9      [9.90616399023427e-08,1.53176385807204e-07]
# 10    [-1.61890227880973e-07,1.46707611793459e-07]
# 11      [9.97414459835983e-08,2.2306553001675e-07]
# 12     [1.97947803531938e-07,3.19358295986344e-07]
# 13     [5.94202283092308e-08,1.66969845077591e-07]
# 14     [1.79466518106826e-07,2.54042701156274e-07]
# 15     [1.73507579138138e-07,3.51939154812369e-07]
# 16    [-4.10437091967078e-08,2.94272244578152e-07]
# 17    [-7.31470600262885e-08,3.23091992962128e-07]
# ...

# %%
metadata.ix[metadata.reg_squared.argsort(), ['Name', 'reg_squared']]
# Out:
#                                 Name  reg_squared
# 10         M. tuberculosis Lineage 2     0.000152
# 24              S. aureus ST8-USA300     0.015295
# 4                      N. meningitis     0.015609
# 34               E. faecium (clade2)     0.020573
# 16  K. pneumoniae CC258 (two clades)     0.033608
# 17     K. pneumoniae CC258 (clade 1)     0.041846
# 1                          Y. pestis     0.061862
# 30               E. faecium (clade1)     0.069713
# 33           E. faecium (two clades)     0.091504
# 26             S. pyogenes (clade 2)     0.096605
# 11               S. pneumoniae PMEN1     0.123387
# 3          M. tuberculosis Lineage 4     0.157756
# 25          S. pyogenes (two clades)     0.174273
# 6           S. Paratyphi A (clade 1)     0.181526
# 13                          S. Agona     0.215408
# 2        Y. pestis (second pandemic)     0.228592
# 20     K. pneumoniae CC258 (clade 2)     0.252052
# 35     M. tuberculosis (NW mummies)      0.287100
# ...

# %%
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# Name: reg_rsquared, dtype: float64

# %%
compare_data = pd.DataFrame([metadata.Name, metadata.beast_genomic_rate, metadata.regression_rate]).transpose()

compare_data
# Out:
#                                 Name beast_genomic_rate regression_rate
# 0                          M. leprae       1.562162e-08    4.629322e-09
# 1                          Y. pestis       1.572643e-08    6.881661e-09
# 2        Y. pestis (second pandemic)       2.260972e-08    -6.26605e-09
# 3          M. tuberculosis Lineage 4       5.675213e-08    6.296575e-08
# 4                      N. meningitis       6.049665e-08    3.082473e-07
# 5        S. Paratyphi A (two clades)       7.604037e-08    5.433314e-08
# 6           S. Paratyphi A (clade 1)       8.016475e-08    4.772121e-08
# 7           S. Paratyphi A (clade 2)       9.473972e-08    6.830678e-08
# 8                       B. pertussis        1.72569e-07    2.509673e-07
# 9                       S. Typhi H58       1.781592e-07     1.26119e-07
# 10         M. tuberculosis Lineage 2       1.926953e-07   -7.591308e-09
# 11               S. pneumoniae PMEN1       2.200994e-07    1.428449e-07
# ...
