# %%
library(ape)

# %%
dir()
# Out:
#  [1] "~$metadata_updated_rates.xlsx"      "A_baumanii_1"
#  [3] "A_baumanii_2"                       "agona_pruned"
#  [5] "all_models.csv"                     "all_regressions"
#  [7] "b_pertussis"                        "base_freqs.csv"
#  [9] "best_models.csv"                    "best_reg_rates_labelled.pdf"
# [11] "best_reg_rates.pdf"                 "compute_stats.R"
# [13] "compute_stats.R~"                   "converted_rates.csv"
# [15] "e_faecium_clade1"                   "e_faecium_clade2"
# [17] "e_faecium_clades12"                 "explore_data.ipynb"
# [19] "fig_1_plots.ipynb"                  "fig_1.pdf"
# [21] "fig_2.pdf"                          "fig1.pdf"
# [23] "Fig2.pdf"                           "Fig3_and_fig4.pdf"
# [25] "Fig3_new.pdf"                       "Fig3.pdf"
# [27] "Fig4.pdf"                           "Fig5.pdf"
# [29] "Fig6_new.pdf"                       "Figure3_titv.pdf"
# [31] "genome_conversion_factors_2.xlsx"   "genome_conversion_factors_3.xlsx"
# ...

# %%
mtub <- read.dna('TB_animals_L6/TB_animal_L6.phy')

# %%
length(seg.sites(mtub))
# Out:
# [1] 7527
